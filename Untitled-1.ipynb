# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
dt = 0.01
'Current simulation'
time = np.arange(0,100,dt)
Im = np.zeros_like(time)
Im[int(5/dt):int(5.5/dt)] = 30  # current pulse at 5 ms for 0.5 ms

# %%
plt.plot(time,Im)
